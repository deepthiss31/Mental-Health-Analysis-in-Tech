# %% [markdown]
# # Mental Health in Tech Survey

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## COUNTRY

# %% [markdown]
# The economic costs of the health system are usually measured by the ratio of health expenditures to gross domestic product (GDP) or – in other words – by the contribution of the health system to GDP. Illness compared to health does not only result in a different disposition of GDP, however, say spending on health services instead of spending on other goods and services, but it also results in a lower size of GDP due to work lost due to illness There are considerable country-to-country differences. In the United States only 2% of annual working time is lost due to illness; in Australia, Canada and Switzerland it is 3% or less.3 In contrast, the corresponding figures are 4.2% for Germany, 5.8% for Austria, and close to 9% in Poland

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
col = pd.read_csv('survey.csv')

# %%
col.iloc[:,3].head()
# Out:
# 0     United States
# 1     United States
# 2            Canada
# 3    United Kingdom
# 4     United States
# Name: Country, dtype: object

# %%
country_list=list(col.iloc[:,3])

# %%
country_dict=dict()
for i in country_list:
    if i not in country_dict:
        country_dict[i]=1
    else:
        country_dict[i]=country_dict[i]+1

print(country_dict)
# Out:
# {'United States': 751, 'Canada': 72, 'United Kingdom': 185, 'Bulgaria': 4, 'France': 13, 'Portugal': 2, 'Netherlands': 27, 'Switzerland': 7, 'Poland': 7, 'Australia': 21, 'Germany': 45, 'Russia': 3, 'Mexico': 3, 'Brazil': 6, 'Slovenia': 1, 'Costa Rica': 1, 'Austria': 3, 'Ireland': 27, 'India': 10, 'South Africa': 6, 'Italy': 7, 'Sweden': 7, 'Colombia': 2, 'Latvia': 1, 'Romania': 1, 'Belgium': 6, 'New Zealand': 8, 'Zimbabwe': 1, 'Spain': 1, 'Finland': 3, 'Uruguay': 1, 'Israel': 5, 'Bosnia and Herzegovina': 1, 'Hungary': 1, 'Singapore': 4, 'Japan': 1, 'Nigeria': 1, 'Croatia': 2, 'Norway': 1, 'Thailand': 1, 'Denmark': 2, 'Bahamas, The': 1, 'Greece': 2, 'Moldova': 1, 'Georgia': 1, 'China': 1, 'Czech Republic': 1, 'Philippines': 1}

# %%
activities=list(country_dict.keys())
slices=list(country_dict.values())

# %%
print(slices)
# Out:
# [751, 72, 185, 4, 13, 2, 27, 7, 7, 21, 45, 3, 3, 6, 1, 1, 3, 27, 10, 6, 7, 7, 2, 1, 1, 6, 8, 1, 1, 3, 1, 5, 1, 1, 4, 1, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1]

# %%
cols=['c','m','r','b','w','gray','silver','gold','tan','bisque','navy','plum','moccasin','k','maroon','coral','olive',
      'yellowgreen','lawngreen','lightgreen','g','skyblue','darkblue','slateblue','crimson','violet','y','pink','purple','aqua',
      'tomato','lime','cornsilk','yellow','indigo','thistle','orchid','lightpink','dimgray','snow','brown','oldlace',
      'palegreen','darkgreen','seagreen','aliceblue']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size 

plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(country_dict.items())
plt.title('country')
plt.show()

# %% [markdown]
# ## GENDER

# %% [markdown]
# We find that depression increases the probability of self-employment by over 13 percent for single men and by over 2% for single women. Having depression or any mental health diagnosis also increases the probability of self-employment for married women by over 4%. Further, we find mixed evidence of how mental health influences the self-employment decisions of married men.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
col.iloc[:,2].head()
# Out:
# 0    Female
# 1         M
# 2      Male
# 3      Male
# 4      Male
# Name: Gender, dtype: object

# %%
Gender_list=list(col.iloc[:,2])
Gender_dict=dict()
for i in Gender_list:
    if i not in Gender_dict:
        Gender_dict[i]=1
    else:
        Gender_dict[i]=Gender_dict[i]+1
print(Gender_dict)
print(len(Gender_dict))
# Out:
# {'Female': 121, 'M': 116, 'Male': 615, 'male': 206, 'female': 62, 'm': 34, 'Male-ish': 1, 'maile': 1, 'Trans-female': 1, 'Cis Female': 1, 'F': 38, 'something kinda male?': 1, 'Cis Male': 2, 'Woman': 3, 'f': 15, 'Mal': 1, 'Male (CIS)': 1, 'queer/she/they': 1, 'non-binary': 1, 'Femake': 1, 'woman': 1, 'Make': 4, 'Nah': 1, 'All': 1, 'Enby': 1, 'fluid': 1, 'Genderqueer': 1, 'Female ': 2, 'Androgyne': 1, 'Agender': 1, 'cis-female/femme': 1, 'Guy (-ish) ^_^': 1, 'male leaning androgynous': 1, 'Male ': 3, 'Man': 2, 'Trans woman': 1, 'msle': 1, 'Neuter': 1, 'Female (trans)': 2, 'queer': 1, 'Female (cis)': 1, 'Mail': 1, 'cis male': 1, 'A little about you': 1, 'Malr': 1, 'p': 1, 'femail': 1, 'Cis Man': 1, 'ostensibly male, unsure what that really means': 1}
# 49

# %%
activities=list(Gender_dict.keys())
slices=list(Gender_dict.values())
cols=['c','m','r','b','w','gray','silver','gold','tan','bisque','navy','plum','moccasin','k','maroon','coral','olive',
      'yellowgreen','lawngreen','lightgreen','g','skyblue','darkblue','slateblue','crimson','violet','y','pink','purple','aqua',
      'tomato','lime','cornsilk','yellow','indigo','thistle','orchid','lightpink','dimgray','snow','brown','oldlace',
      'palegreen','darkgreen','seagreen','aliceblue','black']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(Gender_dict.items())
plt.title('Gender')
plt.show()

# %% [markdown]
# ## AGE

# %% [markdown]
# Stress is high in software profession because of their nature of work, target, achievements, night shift, over work load. IT and IT related professionals are at a constant pressure to deliver services efficiently and have to be cost effective. Employees working in IT industry are prone to develop a lot of health problems due to continuous physical and mental stress of their work. Diseases are either induced, sustained or exacerbated by stress. The common health problem due to stress are acid peptic disease, alcoholism, asthma, diabetes, fatigue, tension headache, hypertension, insomnia, irritable bowel syndrome, psychoneurosis, sexual dysfunction and skin diseases such as psoriasis, lichen planus, urticaria, pruritus, neurodermatitis etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
col.iloc[:,1].head()
# Out:
# 0    37
# 1    44
# 2    32
# 3    31
# 4    31
# Name: Age, dtype: int64

# %%
Age_list=list(col.iloc[:,1])
Age_dict=dict()
for i in Age_list:
    if i not in Age_dict:
        Age_dict[i]=1
    else:
        Age_dict[i]=Age_dict[i]+1
print(Age_dict)
print(len((Age_dict)))
# Out:
# {37: 43, 44: 11, 32: 82, 31: 67, 33: 70, 35: 55, 39: 33, 42: 20, 23: 51, 29: 85, 36: 37, 27: 71, 46: 12, 41: 21, 34: 65, 30: 63, 40: 33, 38: 39, 50: 6, 24: 46, 18: 7, 28: 68, 26: 75, 22: 21, 19: 9, 25: 61, 45: 12, 21: 16, -29: 1, 43: 28, 56: 4, 60: 2, 54: 3, 329: 1, 55: 3, 99999999999: 1, 48: 6, 20: 6, 57: 3, 58: 1, 47: 2, 62: 1, 51: 5, 65: 1, 49: 4, -1726: 1, 5: 1, 53: 1, 61: 1, 8: 1, 11: 1, -1: 1, 72: 1}
# 53

# %%
activities=list(Age_dict.keys())
slices=list(Age_dict.values())
cols=['c','m','r','b','w','gray','silver','gold','tan','bisque','navy','plum','moccasin','k','maroon','coral','olive',
      'yellowgreen','lawngreen','lightgreen','g','skyblue','darkblue','slateblue','crimson','violet','y','pink','purple','aqua',
      'tomato','lime','cornsilk','yellow','indigo','thistle','orchid','lightpink','dimgray','snow','brown','oldlace',
      'palegreen','darkgreen','seagreen','aliceblue','brown','green','pink','violet','darkblue']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(Age_dict.items())
plt.title('Age')
plt.show()

# %% [markdown]
# ## STATE

# %%
col.iloc[:,4].head()
# Out:
# 0     IL
# 1     IN
# 2    NaN
# 3    NaN
# 4     TX
# Name: state, dtype: object

# %%
state_list=list(col.iloc[:,4])
state_dict=dict()
for i in state_list:
    if i not in state_dict:
        state_dict[i]=1
    else:
        state_dict[i]=state_dict[i]+1
print(state_dict)
print(len((state_dict)))
# Out:
# {'IL': 29, 'IN': 27, nan: 515, 'TX': 44, 'TN': 45, 'MI': 22, 'OH': 30, 'CA': 138, 'CT': 4, 'MD': 8, 'NY': 57, 'NC': 14, 'MA': 20, 'IA': 4, 'PA': 29, 'WA': 70, 'WI': 12, 'UT': 11, 'NM': 2, 'OR': 29, 'FL': 15, 'MN': 21, 'MO': 12, 'AZ': 7, 'CO': 9, 'GA': 12, 'DC': 4, 'NE': 2, 'WV': 1, 'OK': 6, 'KS': 3, 'VA': 14, 'NH': 3, 'KY': 5, 'AL': 8, 'NV': 3, 'NJ': 6, 'SC': 5, 'VT': 3, 'SD': 3, 'ID': 1, 'MS': 1, 'RI': 1, 'WY': 2, 'LA': 1, 'ME': 1}
# 46

# %%
activities=list(state_dict.keys())
slices=list(state_dict.values())
cols=['c','m','r','b','w','gray','silver','gold','tan','bisque','navy','plum','moccasin','k','maroon','coral','olive',
      'yellowgreen','lawngreen','lightgreen','g','skyblue','darkblue','slateblue','crimson','violet','y','pink','purple','aqua',
      'tomato','lime','cornsilk','yellow','indigo','thistle','orchid','lightpink','dimgray','snow','brown','oldlace',
      'palegreen','darkgreen']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(state_dict.items())
plt.title('state')
plt.show()

# %% [markdown]
# ## SELF_EMPLOYMENT

# %% [markdown]
# The importance of self-employment to the economy and the traits of successful entrepreneurs has long been an important theme in the business and economics literature. Given the prevalence of mental health problems (close to 30% of the U.S. population experiences at least one mental or substance abuse disorder each year), this paper analyses the role of mental health with regard to self-employment decisions.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
col.iloc[:,5].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: self_employed, dtype: object

# %%
self_employment_list=list(col.iloc[:,5])
self_employment_dict=dict()
for i in self_employment_list:
    if i not in self_employment_dict:
        self_employment_dict[i]=1
    else:
        self_employment_dict[i]=self_employment_dict[i]+1
print(self_employment_dict)
print(len((self_employment_dict)))
# Out:
# {nan: 18, 'Yes': 146, 'No': 1095}
# 3

# %%
activities=list(self_employment_dict.keys())
slices=list(self_employment_dict.values())
cols=['skyblue','darkblue','slateblue']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(self_employment_dict.items())
plt.title('self_employment')
plt.show()

# %% [markdown]
# ### **MENTAL HEALTH BASED ON FAMILY HISTORY**

# %% [markdown]
# *Do you have a family history of mental illness?*

# %% [markdown]
# ![j_ijamh-2017-0035_fig_001.jpg](attachment:j_ijamh-2017-0035_fig_001.jpg)

# %% [markdown]
# col.iloc[:,6].unique()

# %%
family_history_list=list(col.iloc[:,6])
family_history_dict=dict()
for i in family_history_list:
    if i not in family_history_dict:
        family_history_dict[i]=1
    else:
        family_history_dict[i]=family_history_dict[i]+1

print(family_history_dict)
# Out:
# {'No': 767, 'Yes': 492}

# %% [markdown]
# **This analysis was done in different countries in terms of 'YES' or 'NO' out of which 767 were not based on family history and the other 492 were based on family history**

# %%
cols = ['c','m']

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(list(family_history_dict.values()),labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(family_history_dict.items())
plt.title('family_history')
plt.show()

# %% [markdown]
#  **This is represented using a 'PIE CHART' and here we can see that majority of the countries mental health are not based on family history**

# %% [markdown]
# **TREATMENT FOR MENTAL HEALTH CONDITION**

# %% [markdown]
# *Have you sought treatment for mental health condition?*

# %% [markdown]
# ![Dialectical-Behavior-Therapy.jpg](attachment:Dialectical-Behavior-Therapy.jpg)

# %%
col.iloc[:,7].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# **This was also categorized again in two categories i.e, 'YES' or 'NO'**

# %%
treatment_list=list(col.iloc[:,7])
treatment_dict=dict()
for i in treatment_list:
    if i not in treatment_dict:
        treatment_dict[i]=1
    else:
        treatment_dict[i]=treatment_dict[i]+1

print(treatment_dict)
# Out:
# {'Yes': 637, 'No': 622}

# %% [markdown]
# **This data tells us that 637 out of given number of people took treatment for the mental health issues faced by them and 622 number of people did not want to seek treatment**

# %%
cols = ['grey','r']

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(list(treatment_dict.values()),labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(treatment_dict.items())
plt.title('treatment')
plt.show()

# %% [markdown]
# **This analysis is represented using 'PIE CHART'
#   From the chart it is seen that approximately half the number of given population took treatment for the mental issues faced by them and the rest denied to take the treatment**

# %% [markdown]
# ## WORK INTERFERENCE

# %% [markdown]
# *If you have mental health condition,do you feel that it interferes with your work?*

# %% [markdown]
# ![Managing-Stress-at-Work.jpg](attachment:Managing-Stress-at-Work.jpg)

# %%
col.iloc[:,8].unique()
# Out:
# array(['Often', 'Rarely', 'Never', 'Sometimes', nan], dtype=object)

# %% [markdown]
# **This was categorized in to five different categories based on the survey as 'OFTEN','RARELY','NEVER','SOMETIMES','NO ANSWER'**

# %%
work_interfere_list=list(col.iloc[:,8])
work_interfere_dict=dict()
for i in work_interfere_list:
    if i not in work_interfere_dict:
        work_interfere_dict[i]=1
    else:
        work_interfere_dict[i]=work_interfere_dict[i]+1

print(work_interfere_dict)
# Out:
# {'Often': 144, 'Rarely': 173, 'Never': 213, 'Sometimes': 465, nan: 264}

# %%
cols = ['silver','gold','tan','c','pink']

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(list(work_interfere_dict.values()),labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(work_interfere_dict.items())
plt.title('work_interfere')
plt.show()

# %% [markdown]
# **This analysis is represented using 'PIE CHART'
#   It is observed from the representation that the number of people who NEVER experienced mental health issues and the number of people with nuetral answers regarding the mental health issues are almost same.The number of people experiencing the mental health issues OFTEN and the number of people experiencing mental health issues RARELY are approximately equal.Lastly the number of people who experienced the mental health issues SOMETIMES are in majority**

# %% [markdown]
# ## NUMBER OF EMPLOYEES

# %% [markdown]
# *How many employees does your company or organization have?*

# %% [markdown]
# ![employees-working-together-in-the-office-PHCDA9.jpg](attachment:employees-working-together-in-the-office-PHCDA9.jpg)

# %%
col.iloc[:,9].unique()
# Out:
# array(['Jun-25', 'More than 1000', '26-100', '100-500', '01-May',
#        '500-1000'], dtype=object)

# %%
no_employees_list=list(col.iloc[:,9])
no_employees_dict=dict()
for i in no_employees_list:
    if i not in no_employees_dict:
        no_employees_dict[i]=1
    else:
        no_employees_dict[i]=no_employees_dict[i]+1

print(no_employees_dict)
# Out:
# {'Jun-25': 290, 'More than 1000': 282, '26-100': 289, '100-500': 176, '01-May': 162, '500-1000': 60}

# %%
cols = ['c','m','r','b','plum','grey']

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(list(no_employees_dict.values()),labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(no_employees_dict.items())
plt.title('no_employees')
plt.show()

# %% [markdown]
# **This analysis is represented using 'PIE CHART'
#   it gives the number of people joining the company in different months**

# %% [markdown]
# ## REMOTE WORK

# %% [markdown]
# ![lady%20coffee.png](attachment:lady%20coffee.png)

# %% [markdown]
# *Do you work remotely(outside the office)atleast 50% of the time?*

# %%
col.iloc[:,10].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
remote_work_list=list(col.iloc[:,10])
remote_work_dict=dict()
for i in remote_work_list:
    if i not in remote_work_dict:
        remote_work_dict[i]=1
    else:
        remote_work_dict[i]=remote_work_dict[i]+1

print(remote_work_dict)
# Out:
# {'No': 883, 'Yes': 376}

# %%
cols = ['orchid','yellow']

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=10
fig_size[1]=10
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(list(remote_work_dict.values()),labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(remote_work_dict.items())
plt.title('remote_work')
plt.show()

# %% [markdown]
# **This analysis is represented by 'PIE CHART'
#   It is seen from the chart that most number of people are not affected by the mental health caused due to remote work and only a small number of the given population are affected by the mental health issues caused by remote work**

# %% [markdown]
# #**How does the frequency of mental health illness differ by workpace type (i.e., tech vs. non-tech) and size?**

# %%
col.iloc[:,11].head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# Name: tech_company, dtype: object

# %%
tech_company_list=list(col.iloc[:,11])
tech_company=dict()
for i in  tech_company_list:
    if i not in  tech_company:
         tech_company[i]=1
    else:
         tech_company[i]= tech_company[i]+1

print( tech_company)
# Out:
# {'Yes': 1031, 'No': 228}

# %%
activities=list(tech_company.keys())
slices=list(tech_company.values())
cols=['c','m']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(tech_company.items())
plt.title('tech_company')
plt.show()

# %% [markdown]
# The graph shows that the odds of mental health illness among tech companies is significantly
# different than the odds of mental health illness in non-tech companies.

# %%
col.iloc[:,12].head()
# Out:
# 0           Yes
# 1    Don't know
# 2            No
# 3            No
# 4           Yes
# Name: benefits, dtype: object

# %%
benefits_list=list(col.iloc[:,12])
benefits=dict()
for i in   benefits_list:
    if i not in   benefits:
          benefits[i]=1
    else:
          benefits[i]=  benefits[i]+1

print(benefits)
# Out:
# {'Yes': 477, "Don't know": 408, 'No': 374}

# %%
activities=list(benefits.keys())
slices=list(benefits.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(benefits.items())
plt.title('benefits')
plt.show()

# %%
col.iloc[:,13].head()
# Out:
# 0    Not sure
# 1          No
# 2          No
# 3         Yes
# 4          No
# Name: care_options, dtype: object

# %%
care_options_list=list(col.iloc[:,13])
care_options=dict()
for i in   care_options_list:
    if i not in  care_options:
          care_options[i]=1
    else:
          care_options[i]= care_options[i]+1

print(care_options)
# Out:
# {'Not sure': 314, 'No': 501, 'Yes': 444}

# %%
activities=list(care_options.keys())
slices=list(care_options.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(care_options.items())
plt.title('care_options')
plt.show()

# %%
col.iloc[:,14].head()
# Out:
# 0            No
# 1    Don't know
# 2            No
# 3            No
# 4    Don't know
# Name: wellness_program, dtype: object

# %%
wellness_program_list=list(col.iloc[:,14])
wellness_program=dict()
for i in   wellness_program_list:
    if i not in  wellness_program:
          wellness_program[i]=1
    else:
         wellness_program[i]= wellness_program[i]+1

print(wellness_program)
# Out:
# {'No': 842, "Don't know": 188, 'Yes': 229}

# %%
activities=list(wellness_program.keys())
slices=list(wellness_program.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(wellness_program.items())
plt.title('wellness_program')
plt.show()

# %%
col.iloc[:,15].head()
# Out:
# 0           Yes
# 1    Don't know
# 2            No
# 3            No
# 4    Don't know
# Name: seek_help, dtype: object

# %%
seek_help_list=list(col.iloc[:,15])
seek_help=dict()
for i in   seek_help_list:
    if i not in  seek_help:
          seek_help[i]=1
    else:
          seek_help[i]= seek_help[i]+1

print(seek_help)
# Out:
# {'Yes': 250, "Don't know": 363, 'No': 646}

# %%
activities=list(seek_help.keys())
slices=list(seek_help.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(seek_help.items())
plt.title('seek_help')
plt.show()

# %% [markdown]
# **Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?**

# %%
col.iloc[:,16].head()
# Out:
# 0           Yes
# 1    Don't know
# 2    Don't know
# 3            No
# 4    Don't know
# Name: anonymity, dtype: object

# %%
anonymity_list=list(col.iloc[:,16])
anonymity=dict()
for i in  anonymity_list:
    if i not in  anonymity:
         anonymity[i]=1
    else:
        anonymity[i]= anonymity[i]+1

print( anonymity)
# Out:
# {'Yes': 375, "Don't know": 819, 'No': 65}

# %%
activities=list(anonymity.keys())
slices=list(anonymity.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(anonymity.items())
plt.title('anonymity')
plt.show()

# %% [markdown]
# The graph shows that the most of the tech workers don't know about their illness.

# %% [markdown]
# **How easy is it for tech workers to take medical leave for a mental health condition?**

# %%
col.iloc[:,17].head()
# Out:
# 0         Somewhat easy
# 1            Don't know
# 2    Somewhat difficult
# 3    Somewhat difficult
# 4            Don't know
# Name: leave, dtype: object

# %%
leave_list=list(col.iloc[:,17])
leave=dict()
for i in  leave_list:
    if i not in  leave:
        leave[i]=1
    else:
        leave[i]= leave[i]+1

print(leave)
# Out:
# {'Somewhat easy': 266, "Don't know": 563, 'Somewhat difficult': 126, 'Very difficult': 98, 'Very easy': 206}

# %%
activities=list( leave.keys())
slices=list( leave.values())
cols=['c','m','r','darkgreen','yellow']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend( leave.items())
plt.title(' leave')
plt.show()

# %% [markdown]
#  The view of taking leave is different among the tech workers, but most of them dont know about taking leave for mental illness, some of them feel like it is somewhat easy,somewhat difficult,very difficult,very easy.*How tech workers think that discussing a mental health issue with co-employer would have negative consequences?**

# %% [markdown]
# **How tech workers think that discussing a mental health issue with co-employer would have negative consequences?**

# %%
col.iloc[:,18].head()
# Out:
# 0       No
# 1    Maybe
# 2       No
# 3      Yes
# 4       No
# Name: mental_health_consequence, dtype: object

# %%
mental_health_consequence_list=list(col.iloc[:,18])
mental_health_consequence=dict()
for i in   mental_health_consequence_list:
    if i not in  mental_health_consequence:
        mental_health_consequence[i]=1
    else:
         mental_health_consequence[i]= mental_health_consequence[i]+1

print( mental_health_consequence)
# Out:
# {'No': 490, 'Maybe': 477, 'Yes': 292}

# %%
activities=list(mental_health_consequence.keys())
slices=list(mental_health_consequence.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(mental_health_consequence.items())
plt.title('mental_health_consequence')
plt.show()

# %% [markdown]
# some of the tech workers think that discussing a mental health issue with co-employer will have negative consequences

# %% [markdown]
# **How tech workers think that discussing a physical health issue with co-employer would have negative consequences?**

# %%
col.iloc[:,19].head()
# Out:
# 0     No
# 1     No
# 2     No
# 3    Yes
# 4     No
# Name: phys_health_consequence, dtype: object

# %%
phys_health_consequence_list=list(col.iloc[:,19])
phys_health_consequence=dict()
for i in phys_health_consequence_list:
    if i not in   phys_health_consequence:
        phys_health_consequence[i]=1
    else:
        phys_health_consequence[i]=  phys_health_consequence[i]+1

print(phys_health_consequence)
# Out:
# {'No': 925, 'Yes': 61, 'Maybe': 273}

# %%
activities=list(phys_health_consequence.keys())
slices=list(phys_health_consequence.values())
cols=['c','m','r']
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=3
fig_size[1]=3
plt.rcParams["figure.figsize"] = fig_size     
                 
plt.pie(slices,labels=None,colors=cols,startangle=90,shadow=True)
plt.legend(phys_health_consequence.items())
plt.title('phys_health_consequence')
plt.show()

# %% [markdown]
# Most of the tech workers think that discussing a physical health issue with co-employer will not have negative consequences.
